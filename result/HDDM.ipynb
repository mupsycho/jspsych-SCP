# %%
import pandas as pd
import matplotlib.pyplot as plt
import hddm
import kabuki
import ipyparallel

# %%
data = hddm.load_csv('sv02_total.csv')
data = data[data.blockType == "formal"]
data = data[data.series == 1]
data = data[data.rt > 0]
data.head(10)
# Out:
#          index  subj_idx Name   Sex  BirthYear   Education  \
# 1412  sv020002  sv020002  龚天瑜  male       2000  university
# 1417  sv020002  sv020002  龚天瑜  male       2000  university
# 1418  sv020002  sv020002  龚天瑜  male       2000  university
# 1419  sv020002  sv020002  龚天瑜  male       2000  university
# 1421  sv020002  sv020002  龚天瑜  male       2000  university
# 1422  sv020002  sv020002  龚天瑜  male       2000  university
# 1423  sv020002  sv020002  龚天瑜  male       2000  university
# 1424  sv020002  sv020002  龚天瑜  male       2000  university
# 1425  sv020002  sv020002  龚天瑜  male       2000  university
# 1426  sv020002  sv020002  龚天瑜  male       2000  university
#
#                                             PhoneNumber shapeFileName shape  \
# 1412  sRmzm+P9VQE79Jl6b+NHP7whuhEcWsaEzeBhoMhU/YfQNg...       Squ.png   Squ
# 1417  sRmzm+P9VQE79Jl6b+NHP7whuhEcWsaEzeBhoMhU/YfQNg...       Pen.png   Pen
# 1418  sRmzm+P9VQE79Jl6b+NHP7whuhEcWsaEzeBhoMhU/YfQNg...       Tri.png   Tri
# 1419  sRmzm+P9VQE79Jl6b+NHP7whuhEcWsaEzeBhoMhU/YfQNg...       Cir.png   Cir
# 1421  sRmzm+P9VQE79Jl6b+NHP7whuhEcWsaEzeBhoMhU/YfQNg...       Cir.png   Cir
# 1422  sRmzm+P9VQE79Jl6b+NHP7whuhEcWsaEzeBhoMhU/YfQNg...       Pen.png   Pen
# 1423  sRmzm+P9VQE79Jl6b+NHP7whuhEcWsaEzeBhoMhU/YfQNg...       Squ.png   Squ
# 1424  sRmzm+P9VQE79Jl6b+NHP7whuhEcWsaEzeBhoMhU/YfQNg...       Tri.png   Tri
# 1425  sRmzm+P9VQE79Jl6b+NHP7whuhEcWsaEzeBhoMhU/YfQNg...       Tri.png   Tri
# 1426  sRmzm+P9VQE79Jl6b+NHP7whuhEcWsaEzeBhoMhU/YfQNg...       Cir.png   Cir
#
#        shapeEn  ... subjResp series condition block  blockType trial response  \
# 1412    square  ...        n      1     match   NaN     formal   NaN        1
# 1417  pentagon  ...        m      1  mismatch   NaN     formal   NaN        1
# 1418  triangle  ...        n      1     match   NaN     formal   NaN        1
# 1419  circular  ...        m      1     match   NaN     formal   NaN        0
# 1421  circular  ...        m      1  mismatch   NaN     formal   NaN        1
# 1422  pentagon  ...        m      1  mismatch   NaN     formal   NaN        1
# 1423    square  ...        n      1     match   NaN     formal   NaN        1
# 1424  triangle  ...        n      1     match   NaN     formal   NaN        1
# 1425  triangle  ...        m      1  mismatch   NaN     formal   NaN        1
# 1426  circular  ...        m      1  mismatch   NaN     formal   NaN        1
#
#       acc      rt  time_elapsed
# 1412    1  1275.5        797379
# 1417    1  1891.0        813683
# 1418    1   878.5        815764
# 1419    0  1548.5        818514
# 1421    1  1823.2        824843
# 1422    1  1164.5        827211
# 1423    1   726.3        829139
# 1424    1  1252.3        831594
# 1425    1  1485.0        834282
# 1426    1  1366.2        836851
#
# [10 rows x 26 columns]

# %%
m = hddm.HDDMStimCoding(data, 
                                    include='z', 
                                    stim_col='shape', 
                                    depends_on={'v':['misNum']},
                                    split_param='v', 
                                    drift_criterion=False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-edd754debd8d> in <module>
# ----> 1 M_match_vtz_s = hddm.HDDMStimCoding(data,
#       2                                     include='z',
#       3                                     stim_col='shape',
#       4                                     depends_on={'v':['condition','index']},
#       5                                     split_param='v',
#
# /www/wwwroot/psylab2.muxinsq.com/.venv/lib/python3.8/site-packages/hddm/models/hddm_stimcoding.py in __init__(self, *args, **kwargs)
#      46
#      47         self.stims = np.asarray(np.sort(np.unique(args[0][self.stim_col])))
# ---> 48         assert len(self.stims) == 2, "%s must contain two stimulus types" % self.stim_col
#      49
#      50         super(HDDMStimCoding, self).__init__(*args, **kwargs)
#
# AssertionError: shape must contain two stimulus types

# %%
m = hddm.HDDM(data)
m.find_starting_values()
m.sample(2000, burn=20)
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/optimize.py:2215: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/optimize.py:2215: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/optimize.py:2215: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/optimize.py:2215: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [---------        25%                  ] 511 of 2000 complete in 82.9 secHalting at iteration  510  of  2000
